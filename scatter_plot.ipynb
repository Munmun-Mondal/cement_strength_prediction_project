# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv(r'C:\Users\MUNMUN\Documents\machine_learning\Concrete_Data.csv')
df
# Out:
#       Cement (component 1)(kg in a m^3 mixture)  \
# 0                                         540.0
# 1                                         540.0
# 2                                         332.5
# 3                                         332.5
# 4                                         198.6
# ...                                         ...
# 1025                                      276.4
# 1026                                      322.2
# 1027                                      148.5
# 1028                                      159.1
# 1029                                      260.9
#
#       Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# 0                                                   0.0
# 1                                                   0.0
# 2                                                 142.5
# 3                                                 142.5
# 4                                                 132.4
# ...

# %%
df1 = df.select_dtypes(include=['int64', 'float64']).columns
print(df1)
# Out:
# Index(['Cement (component 1)(kg in a m^3 mixture)',
#        'Blast Furnace Slag (component 2)(kg in a m^3 mixture)',
#        'Fly Ash (component 3)(kg in a m^3 mixture)',
#        'Water  (component 4)(kg in a m^3 mixture)',
#        'Superplasticizer (component 5)(kg in a m^3 mixture)',
#        'Coarse Aggregate  (component 6)(kg in a m^3 mixture)',
#        'Fine Aggregate (component 7)(kg in a m^3 mixture)', 'Age (day)',
#        'Concrete compressive strength(MPa, megapascals) '],
#       dtype='object')

# %%
x=df["Cement (component 1)(kg in a m^3 mixture)"]
y=["Blast Furnace Slag (component 2)(kg in a m^3 mixture)"]
plt.figure(figsize=(5,4))
plt.scatter(x="Cement (component 1)(kg in a m^3 mixture)",y="Blast Furnace Slag (component 2)(kg in a m^3 mixture)",c="r")
plt.title("Cement strangth prediction")
plt.xlabel("Cement (component 1)(kg in a m^3 mixture)")
plt.ylabel("Blast Furnace Slag (component 2)(kg in a m^3 mixture)")
# Out:
# Text(0, 0.5, 'Blast Furnace Slag (component 2)(kg in a m^3 mixture)')

# %%
x=df["Cement (component 1)(kg in a m^3 mixture)"]
y=df["Blast Furnace Slag (component 2)(kg in a m^3 mixture)"]
plt.figure(figsize=(10,9))
plt.scatter(x,y,c="r")
plt.title("Cement strangth prediction")
plt.xlabel("Cement (component 1)(kg in a m^3 mixture)")
plt.ylabel("Blast Furnace Slag (component 2)(kg in a m^3 mixture)")
# Out:
# Text(0, 0.5, 'Blast Furnace Slag (component 2)(kg in a m^3 mixture)')

# %%
plt.title("Cement strangth prediction")
sns.scatterplot(x="Cement (component 1)(kg in a m^3 mixture)",y="Blast Furnace Slag (component 2)(kg in a m^3 mixture)",data=df)
# Out:
# <Axes: title={'center': 'Cement strangth prediction'}, xlabel='Cement (component 1)(kg in a m^3 mixture)', ylabel='Blast Furnace Slag (component 2)(kg in a m^3 mixture)'>

# %%
plt.title("Cement strangth prediction")
sns.scatterplot(x="Cement (component 1)(kg in a m^3 mixture)",y="Blast Furnace Slag (component 2)(kg in a m^3 mixture)",hue="Fly Ash (component 3)(kg in a m^3 mixture)",data=df)
# Out:
# <Axes: title={'center': 'Cement strangth prediction'}, xlabel='Cement (component 1)(kg in a m^3 mixture)', ylabel='Blast Furnace Slag (component 2)(kg in a m^3 mixture)'>

# %%
plt.title("Cement strangth prediction")
sns.scatterplot(x="Cement (component 1)(kg in a m^3 mixture)",y="Fly Ash (component 3)(kg in a m^3 mixture)",data=df)
# Out:
# <Axes: title={'center': 'Cement strangth prediction'}, xlabel='Cement (component 1)(kg in a m^3 mixture)', ylabel='Fly Ash (component 3)(kg in a m^3 mixture)'>

# %%
plt.title("Cement strangth prediction")
sns.scatterplot(x="Cement (component 1)(kg in a m^3 mixture)",y="Water  (component 4)(kg in a m^3 mixture)",data=df)
# Out:
# <Axes: title={'center': 'Cement strangth prediction'}, xlabel='Cement (component 1)(kg in a m^3 mixture)', ylabel='Water  (component 4)(kg in a m^3 mixture)'>

# %%
plt.title("Cement strangth prediction")
sns.scatterplot(x="Cement (component 1)(kg in a m^3 mixture)",y="Superplasticizer (component 5)(kg in a m^3 mixture)",data=df)
# Out:
# <Axes: title={'center': 'Cement strangth prediction'}, xlabel='Cement (component 1)(kg in a m^3 mixture)', ylabel='Superplasticizer (component 5)(kg in a m^3 mixture)'>

# %%
plt.title("Cement strangth prediction")
sns.scatterplot(x="Cement (component 1)(kg in a m^3 mixture)",y="Coarse Aggregate  (component 6)(kg in a m^3 mixture)",data=df)
# Out:
# <Axes: title={'center': 'Cement strangth prediction'}, xlabel='Cement (component 1)(kg in a m^3 mixture)', ylabel='Coarse Aggregate  (component 6)(kg in a m^3 mixture)'>

# %%
plt.title("Cement strangth prediction")
sns.scatterplot(x="Cement (component 1)(kg in a m^3 mixture)",y="Fine Aggregate (component 7)(kg in a m^3 mixture)",data=df)
# Out:
# <Axes: title={'center': 'Cement strangth prediction'}, xlabel='Cement (component 1)(kg in a m^3 mixture)', ylabel='Fine Aggregate (component 7)(kg in a m^3 mixture)'>

# %%
plt.title("Cement strangth prediction")
sns.scatterplot(x="Cement (component 1)(kg in a m^3 mixture)",y="Age (day)",data=df)
# Out:
# <Axes: title={'center': 'Cement strangth prediction'}, xlabel='Cement (component 1)(kg in a m^3 mixture)', ylabel='Age (day)'>

# %%
df1 = df.select_dtypes(include=['int64', 'float64']).columns
print(df1)
# Out:
# Index(['Cement (component 1)(kg in a m^3 mixture)',
#        'Blast Furnace Slag (component 2)(kg in a m^3 mixture)',
#        'Fly Ash (component 3)(kg in a m^3 mixture)',
#        'Water  (component 4)(kg in a m^3 mixture)',
#        'Superplasticizer (component 5)(kg in a m^3 mixture)',
#        'Coarse Aggregate  (component 6)(kg in a m^3 mixture)',
#        'Fine Aggregate (component 7)(kg in a m^3 mixture)', 'Age (day)',
#        'Concrete compressive strength(MPa, megapascals) '],
#       dtype='object')

# %%
plt.title("Cement strangth prediction")
sns.scatterplot(x="Blast Furnace Slag (component 2)(kg in a m^3 mixture)",y="Fly Ash (component 3)(kg in a m^3 mixture)",data=df)
# Out:
# <Axes: title={'center': 'Cement strangth prediction'}, xlabel='Blast Furnace Slag (component 2)(kg in a m^3 mixture)', ylabel='Fly Ash (component 3)(kg in a m^3 mixture)'>

# %%
plt.title("Cement strangth prediction")
sns.scatterplot(x="Blast Furnace Slag (component 2)(kg in a m^3 mixture)",y="Water  (component 4)(kg in a m^3 mixture)",data=df)
# Out:
# <Axes: title={'center': 'Cement strangth prediction'}, xlabel='Blast Furnace Slag (component 2)(kg in a m^3 mixture)', ylabel='Water  (component 4)(kg in a m^3 mixture)'>

# %%
plt.title("Cement strangth prediction")
sns.scatterplot(x="Blast Furnace Slag (component 2)(kg in a m^3 mixture)",y="Superplasticizer (component 5)(kg in a m^3 mixture)",data=df)
# Out:
# <Axes: title={'center': 'Cement strangth prediction'}, xlabel='Blast Furnace Slag (component 2)(kg in a m^3 mixture)', ylabel='Superplasticizer (component 5)(kg in a m^3 mixture)'>

# %%
plt.title("Cement strangth prediction")
sns.scatterplot(x="Blast Furnace Slag (component 2)(kg in a m^3 mixture)",y="Coarse Aggregate  (component 6)(kg in a m^3 mixture)",data=df)
# Out:
# <Axes: title={'center': 'Cement strangth prediction'}, xlabel='Blast Furnace Slag (component 2)(kg in a m^3 mixture)', ylabel='Coarse Aggregate  (component 6)(kg in a m^3 mixture)'>

# %%
plt.title("Cement strangth prediction")
sns.scatterplot(x="Blast Furnace Slag (component 2)(kg in a m^3 mixture)",y="Fine Aggregate (component 7)(kg in a m^3 mixture)",data=df)
# Out:
# <Axes: title={'center': 'Cement strangth prediction'}, xlabel='Blast Furnace Slag (component 2)(kg in a m^3 mixture)', ylabel='Fine Aggregate (component 7)(kg in a m^3 mixture)'>

# %%
plt.title("Cement strangth prediction")
sns.scatterplot(x="Blast Furnace Slag (component 2)(kg in a m^3 mixture)",y="Age (day)",data=df)
# Out:
# <Axes: title={'center': 'Cement strangth prediction'}, xlabel='Blast Furnace Slag (component 2)(kg in a m^3 mixture)', ylabel='Age (day)'>

# %%
df1 = df.select_dtypes(include=['int64', 'float64']).columns
print(df1)
# Out:
# Index(['Cement (component 1)(kg in a m^3 mixture)',
#        'Blast Furnace Slag (component 2)(kg in a m^3 mixture)',
#        'Fly Ash (component 3)(kg in a m^3 mixture)',
#        'Water  (component 4)(kg in a m^3 mixture)',
#        'Superplasticizer (component 5)(kg in a m^3 mixture)',
#        'Coarse Aggregate  (component 6)(kg in a m^3 mixture)',
#        'Fine Aggregate (component 7)(kg in a m^3 mixture)', 'Age (day)',
#        'Concrete compressive strength(MPa, megapascals) '],
#       dtype='object')

# %%
plt.title("Cement strangth prediction")
sns.scatterplot(x="Fly Ash (component 3)(kg in a m^3 mixture)",y="Water  (component 4)(kg in a m^3 mixture)",data=df)
# Out:
# <Axes: title={'center': 'Cement strangth prediction'}, xlabel='Fly Ash (component 3)(kg in a m^3 mixture)', ylabel='Water  (component 4)(kg in a m^3 mixture)'>

# %%
plt.title("Cement strangth prediction")
sns.scatterplot(x="Fly Ash (component 3)(kg in a m^3 mixture)",y="Superplasticizer (component 5)(kg in a m^3 mixture)",data=df)
# Out:
# <Axes: title={'center': 'Cement strangth prediction'}, xlabel='Fly Ash (component 3)(kg in a m^3 mixture)', ylabel='Superplasticizer (component 5)(kg in a m^3 mixture)'>

# %%
plt.title("Cement strangth prediction")
sns.scatterplot(x="Fly Ash (component 3)(kg in a m^3 mixture)",y="Coarse Aggregate  (component 6)(kg in a m^3 mixture)",data=df)
# Out:
# <Axes: title={'center': 'Cement strangth prediction'}, xlabel='Fly Ash (component 3)(kg in a m^3 mixture)', ylabel='Coarse Aggregate  (component 6)(kg in a m^3 mixture)'>

# %%
plt.title("Cement strangth prediction")
sns.scatterplot(x="Fly Ash (component 3)(kg in a m^3 mixture)",y="Fine Aggregate (component 7)(kg in a m^3 mixture)",data=df)
# Out:
# <Axes: title={'center': 'Cement strangth prediction'}, xlabel='Fly Ash (component 3)(kg in a m^3 mixture)', ylabel='Fine Aggregate (component 7)(kg in a m^3 mixture)'>

# %%
plt.title("Cement strangth prediction")
sns.scatterplot(x="Fly Ash (component 3)(kg in a m^3 mixture)",y="Age (day)",data=df)
# Out:
# <Axes: title={'center': 'Cement strangth prediction'}, xlabel='Fly Ash (component 3)(kg in a m^3 mixture)', ylabel='Age (day)'>

# %%
df1 = df.select_dtypes(include=['int64', 'float64']).columns
print(df1)
# Out:
# Index(['Cement (component 1)(kg in a m^3 mixture)',
#        'Blast Furnace Slag (component 2)(kg in a m^3 mixture)',
#        'Fly Ash (component 3)(kg in a m^3 mixture)',
#        'Water  (component 4)(kg in a m^3 mixture)',
#        'Superplasticizer (component 5)(kg in a m^3 mixture)',
#        'Coarse Aggregate  (component 6)(kg in a m^3 mixture)',
#        'Fine Aggregate (component 7)(kg in a m^3 mixture)', 'Age (day)',
#        'Concrete compressive strength(MPa, megapascals) '],
#       dtype='object')

# %%
plt.title("Cement strangth prediction")
sns.scatterplot(x="Water  (component 4)(kg in a m^3 mixture)",y="Superplasticizer (component 5)(kg in a m^3 mixture)",data=df)
# Out:
# <Axes: title={'center': 'Cement strangth prediction'}, xlabel='Water  (component 4)(kg in a m^3 mixture)', ylabel='Superplasticizer (component 5)(kg in a m^3 mixture)'>

# %%
plt.title("Cement strangth prediction")
sns.scatterplot(x="Water  (component 4)(kg in a m^3 mixture)",y="Coarse Aggregate  (component 6)(kg in a m^3 mixture)",data=df)
# Out:
# <Axes: title={'center': 'Cement strangth prediction'}, xlabel='Water  (component 4)(kg in a m^3 mixture)', ylabel='Coarse Aggregate  (component 6)(kg in a m^3 mixture)'>

# %%
plt.title("Cement strangth prediction")
sns.scatterplot(x="Water  (component 4)(kg in a m^3 mixture)",y="Fine Aggregate (component 7)(kg in a m^3 mixture)",data=df)
# Out:
# <Axes: title={'center': 'Cement strangth prediction'}, xlabel='Water  (component 4)(kg in a m^3 mixture)', ylabel='Fine Aggregate (component 7)(kg in a m^3 mixture)'>

# %%
plt.title("Cement strangth prediction")
sns.scatterplot(x="Water  (component 4)(kg in a m^3 mixture)",y="Age (day)",data=df)
# Out:
# <Axes: title={'center': 'Cement strangth prediction'}, xlabel='Water  (component 4)(kg in a m^3 mixture)', ylabel='Age (day)'>

# %%
df1 = df.select_dtypes(include=['int64', 'float64']).columns
print(df1)
# Out:
# Index(['Cement (component 1)(kg in a m^3 mixture)',
#        'Blast Furnace Slag (component 2)(kg in a m^3 mixture)',
#        'Fly Ash (component 3)(kg in a m^3 mixture)',
#        'Water  (component 4)(kg in a m^3 mixture)',
#        'Superplasticizer (component 5)(kg in a m^3 mixture)',
#        'Coarse Aggregate  (component 6)(kg in a m^3 mixture)',
#        'Fine Aggregate (component 7)(kg in a m^3 mixture)', 'Age (day)',
#        'Concrete compressive strength(MPa, megapascals) '],
#       dtype='object')

# %%
plt.title("Cement strangth prediction")
sns.scatterplot(x="Superplasticizer (component 5)(kg in a m^3 mixture)",y="Coarse Aggregate  (component 6)(kg in a m^3 mixture)",data=df)
# Out:
# <Axes: title={'center': 'Cement strangth prediction'}, xlabel='Superplasticizer (component 5)(kg in a m^3 mixture)', ylabel='Coarse Aggregate  (component 6)(kg in a m^3 mixture)'>

# %%
plt.title("Cement strangth prediction")
sns.scatterplot(x="Superplasticizer (component 5)(kg in a m^3 mixture)",y="Fine Aggregate (component 7)(kg in a m^3 mixture)",data=df)
# Out:
# <Axes: title={'center': 'Cement strangth prediction'}, xlabel='Superplasticizer (component 5)(kg in a m^3 mixture)', ylabel='Fine Aggregate (component 7)(kg in a m^3 mixture)'>

# %%
plt.title("Cement strangth prediction")
sns.scatterplot(x="Superplasticizer (component 5)(kg in a m^3 mixture)",y="Age (day)",data=df)
# Out:
# <Axes: title={'center': 'Cement strangth prediction'}, xlabel='Superplasticizer (component 5)(kg in a m^3 mixture)', ylabel='Age (day)'>

# %%
df1 = df.select_dtypes(include=['int64', 'float64']).columns
print(df1)
# Out:
# Index(['Cement (component 1)(kg in a m^3 mixture)',
#        'Blast Furnace Slag (component 2)(kg in a m^3 mixture)',
#        'Fly Ash (component 3)(kg in a m^3 mixture)',
#        'Water  (component 4)(kg in a m^3 mixture)',
#        'Superplasticizer (component 5)(kg in a m^3 mixture)',
#        'Coarse Aggregate  (component 6)(kg in a m^3 mixture)',
#        'Fine Aggregate (component 7)(kg in a m^3 mixture)', 'Age (day)',
#        'Concrete compressive strength(MPa, megapascals) '],
#       dtype='object')

# %%
plt.title("Cement strangth prediction")
sns.scatterplot(x="Coarse Aggregate  (component 6)(kg in a m^3 mixture)",y="Fine Aggregate (component 7)(kg in a m^3 mixture)",data=df)
# Out:
# <Axes: title={'center': 'Cement strangth prediction'}, xlabel='Coarse Aggregate  (component 6)(kg in a m^3 mixture)', ylabel='Fine Aggregate (component 7)(kg in a m^3 mixture)'>

# %%
plt.title("Cement strangth prediction")
sns.scatterplot(x="Coarse Aggregate  (component 6)(kg in a m^3 mixture)",y="Age (day)",data=df)
# Out:
# <Axes: title={'center': 'Cement strangth prediction'}, xlabel='Coarse Aggregate  (component 6)(kg in a m^3 mixture)', ylabel='Age (day)'>

# %%
df1 = df.select_dtypes(include=['int64', 'float64']).columns
print(df1)
# Out:
# Index(['Cement (component 1)(kg in a m^3 mixture)',
#        'Blast Furnace Slag (component 2)(kg in a m^3 mixture)',
#        'Fly Ash (component 3)(kg in a m^3 mixture)',
#        'Water  (component 4)(kg in a m^3 mixture)',
#        'Superplasticizer (component 5)(kg in a m^3 mixture)',
#        'Coarse Aggregate  (component 6)(kg in a m^3 mixture)',
#        'Fine Aggregate (component 7)(kg in a m^3 mixture)', 'Age (day)',
#        'Concrete compressive strength(MPa, megapascals) '],
#       dtype='object')

# %%
plt.title("Cement strangth prediction")
sns.scatterplot(x="Fine Aggregate (component 7)(kg in a m^3 mixture)",y="Age (day)",data=df)
# Out:
# <Axes: title={'center': 'Cement strangth prediction'}, xlabel='Fine Aggregate (component 7)(kg in a m^3 mixture)', ylabel='Age (day)'>

# %%
plt.title("Cement strangth prediction")
sns.scatterplot(x="Cement (component 1)(kg in a m^3 mixture)",y="Blast Furnace Slag (component 2)(kg in a m^3 mixture)",hue="Water  (component 4)(kg in a m^3 mixture)",data=df)
# Out:
# <Axes: title={'center': 'Cement strangth prediction'}, xlabel='Cement (component 1)(kg in a m^3 mixture)', ylabel='Blast Furnace Slag (component 2)(kg in a m^3 mixture)'>

# %%
plt.title("Cement strangth prediction")
sns.scatterplot(x="Cement (component 1)(kg in a m^3 mixture)",y="Blast Furnace Slag (component 2)(kg in a m^3 mixture)",hue="Age (day)",data=df)
# Out:
# <Axes: title={'center': 'Cement strangth prediction'}, xlabel='Cement (component 1)(kg in a m^3 mixture)', ylabel='Blast Furnace Slag (component 2)(kg in a m^3 mixture)'>

# %%
plt.title("Cement strangth prediction")
sns.scatterplot(x="Cement (component 1)(kg in a m^3 mixture)",y="Concrete compressive strength(MPa, megapascals)",data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\MUNMUN\Documents\machine_learning\scatter_plot.ipynb Cell 42 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/MUNMUN/Documents/machine_learning/scatter_plot.ipynb#X56sZmlsZQ%3D%3D?line=0'>1</a> plt.title("Cement strangth prediction")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/MUNMUN/Documents/machine_learning/scatter_plot.ipynb#X56sZmlsZQ%3D%3D?line=1'>2</a> sns.scatterplot(x="Cement (component 1)(kg in a m^3 mixture)",y="Concrete compressive strength(MPa, megapascals)",data=df)
#
# File c:\Users\MUNMUN\anaconda3\Lib\site-packages\seaborn\relational.py:742, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     732 def scatterplot(
#     733     data=None, *,
# ...
