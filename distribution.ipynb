# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv(r'C:\Users\MUNMUN\Documents\machine_learning\Concrete_Data.csv')
df
# Out:
#       Cement (component 1)(kg in a m^3 mixture)  \
# 0                                         540.0
# 1                                         540.0
# 2                                         332.5
# 3                                         332.5
# 4                                         198.6
# ...                                         ...
# 1025                                      276.4
# 1026                                      322.2
# 1027                                      148.5
# 1028                                      159.1
# 1029                                      260.9
#
#       Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# 0                                                   0.0
# 1                                                   0.0
# 2                                                 142.5
# 3                                                 142.5
# 4                                                 132.4
# ...

# %%
df1 = df.select_dtypes(include=['int64', 'float64']).columns
print(df1)
# Out:
# Index(['Cement (component 1)(kg in a m^3 mixture)',
#        'Blast Furnace Slag (component 2)(kg in a m^3 mixture)',
#        'Fly Ash (component 3)(kg in a m^3 mixture)',
#        'Water  (component 4)(kg in a m^3 mixture)',
#        'Superplasticizer (component 5)(kg in a m^3 mixture)',
#        'Coarse Aggregate  (component 6)(kg in a m^3 mixture)',
#        'Fine Aggregate (component 7)(kg in a m^3 mixture)', 'Age (day)',
#        'Concrete compressive strength(MPa, megapascals) '],
#       dtype='object')

# %%
sns.displot(x="Cement (component 1)(kg in a m^3 mixture)",data=df)

# %%
sns.displot(x="Blast Furnace Slag (component 2)(kg in a m^3 mixture)",data=df)

# %%
sns.displot(x="Fly Ash (component 3)(kg in a m^3 mixture)",data=df)

# %%
sns.displot(x="Water  (component 4)(kg in a m^3 mixture)",data=df)

# %%
sns.displot(x="Superplasticizer (component 5)(kg in a m^3 mixture)",data=df)

# %%
sns.displot(x="Coarse Aggregate  (component 6)(kg in a m^3 mixture)",data=df)

# %%
sns.displot(x="Fine Aggregate (component 7)(kg in a m^3 mixture)",data=df)

# %%
sns.displot(x="Age (day)",data=df)
